# %%
include("utils.jl")
# Out:
# isComputeS (generic function with 1 method)

# %%
H = buildHbdG(1.0, 2)
# Out:
# 4×4 SparseMatrixCSC{ComplexF64, Int64} with 8 stored entries:
#       ⋅      -0.5+0.0im      ⋅      -0.5-0.0im
#  -0.5+0.0im       ⋅      0.5+0.0im       ⋅
#       ⋅       0.5+0.0im      ⋅       0.5+0.0im
#  -0.5-0.0im       ⋅      0.5+0.0im       ⋅

# %%
G = GInit(2)
# Out:
# 4×4 Matrix{ComplexF64}:
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  1.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  1.0+0.0im

# %%
10 % 5
# Out:
# 0

# %%
isComputeS(210, 0.01)
# Out:
# false

# %%
rand(1:1000)
# Out:
# 950
